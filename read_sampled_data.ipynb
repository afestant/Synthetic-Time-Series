# %%
import datetime
import yaml
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'test_CNN_dis_LSTM_gen.npy'

# %%
X = np.load(filename, mmap_mode='r')

# %%
X.shape
# Out:
# (4, 30, 1)

# %%
data = pd.DataFrame(X.reshape(4,30).T)

# %%
data.head()
# Out:
#            0          1          2          3
# 0  35.624073  35.585449  35.406693  35.028702
# 1  35.341553  35.447777  35.499020  35.632847
# 2  35.006783  35.437000  35.427578  35.503784
# 3  35.471584  35.270260  35.840313  34.869980
# 4  35.424866  34.790352  35.389381  35.504303

# %%
p = data.plot.line()
